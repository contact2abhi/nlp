# %% [markdown]
# <a href="https://colab.research.google.com/github/contact2abhi/nlp/blob/main/spacy_POS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise to grab important tokens out of text

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("""History
Formation and early years
In 1976, a group of eight engineers, all former employees of Delhi Cloth & General Mills, led by Shiv Nadar, started a company that would make personal computers.[10][11] Initially floated as Microcomp Limited, Nadar and his team (which also included Arjun Malhotra, Ajai Chowdhry, D.S. Puri, Yogesh Vaidya and Subhash Arora) started selling teledigital calculators to gather capital for their main product. On 11 August 1976, the company was renamed Hindustan Computers Limited (HCL).[12] HCL Enterprise developed an indigenous microcomputer in 1978,[13] and a RDBMS, networking OS and client-server architecture in 1983.[14] HCL Technologies began as the R&D division of HCL Enterprise.[15]

The company originally was focused on hardware but, via HCL Technologies, software and services became the main focus.[16][17] On 12 November 1991, HCL Technologies was spun off as a separate unit,[18] being incorporated as HCL Overseas Limited, a provider of software and technology development services.[19]

In 1993, HCL also started providing enterprise IT infrastructure management services, winning an order to establish India's first floorless, electronic stock exchange for NSE.[20][21]

In July 1994, the company name was changed to HCL Consulting Limited.[22] On 6 October 1999, the company was renamed 'HCL Technologies Limited' for "a better reflection of its activities."[19]""")

# %%
filtered_tokens = []
for token in doc:
  if token.pos_ not in ["SPACE", "PUNCT", "X"]:
    filtered_tokens.append(token)
for token in filtered_tokens:
  print(token.text , " = ", token.pos_ , "(", spacy.explain(token.pos_) ,")", "tag =" , spacy.explain(token.tag_))
# Out:
# History  =  NOUN ( noun ) tag = noun, singular or mass
# Formation  =  PROPN ( proper noun ) tag = noun, proper singular
# and  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# early  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# years  =  NOUN ( noun ) tag = noun, plural
# In  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# 1976  =  NUM ( numeral ) tag = cardinal number
# a  =  DET ( determiner ) tag = determiner
# group  =  NOUN ( noun ) tag = noun, singular or mass
# of  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# eight  =  NUM ( numeral ) tag = cardinal number
# engineers  =  NOUN ( noun ) tag = noun, plural
# all  =  DET ( determiner ) tag = determiner
# former  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# employees  =  NOUN ( noun ) tag = noun, plural
# of  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# Delhi  =  PROPN ( proper noun ) tag = noun, proper singular
# Cloth  =  PROPN ( proper noun ) tag = noun, proper singular
# &  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# General  =  PROPN ( proper noun ) tag = noun, proper singular
# Mills  =  PROPN ( proper noun ) tag = noun, proper singular
# led  =  VERB ( verb ) tag = verb, past participle
# by  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# Shiv  =  PROPN ( proper noun ) tag = noun, proper singular
# Nadar  =  PROPN ( proper noun ) tag = noun, proper singular
# started  =  VERB ( verb ) tag = verb, past tense
# a  =  DET ( determiner ) tag = determiner
# company  =  NOUN ( noun ) tag = noun, singular or mass
# that  =  PRON ( pronoun ) tag = wh-determiner
# would  =  AUX ( auxiliary ) tag = verb, modal auxiliary
# make  =  VERB ( verb ) tag = verb, base form
# personal  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# computers.[10][11  =  NOUN ( noun ) tag = noun, singular or mass
# Initially  =  ADV ( adverb ) tag = adverb
# floated  =  VERB ( verb ) tag = verb, past tense
# as  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# Microcomp  =  PROPN ( proper noun ) tag = noun, proper singular
# Limited  =  PROPN ( proper noun ) tag = noun, proper singular
# Nadar  =  PROPN ( proper noun ) tag = noun, proper singular
# and  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# his  =  PRON ( pronoun ) tag = pronoun, possessive
# team  =  NOUN ( noun ) tag = noun, singular or mass
# which  =  PRON ( pronoun ) tag = wh-determiner
# also  =  ADV ( adverb ) tag = adverb
# included  =  VERB ( verb ) tag = verb, past tense
# Arjun  =  PROPN ( proper noun ) tag = noun, proper singular
# Malhotra  =  PROPN ( proper noun ) tag = noun, proper singular
# Ajai  =  PROPN ( proper noun ) tag = noun, proper singular
# Chowdhry  =  PROPN ( proper noun ) tag = noun, proper singular
# D.S.  =  PROPN ( proper noun ) tag = noun, proper singular
# Puri  =  PROPN ( proper noun ) tag = noun, proper singular
# Yogesh  =  PROPN ( proper noun ) tag = noun, proper singular
# Vaidya  =  PROPN ( proper noun ) tag = noun, proper singular
# and  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# Subhash  =  PROPN ( proper noun ) tag = noun, proper singular
# Arora  =  PROPN ( proper noun ) tag = noun, proper singular
# started  =  VERB ( verb ) tag = verb, past tense
# selling  =  VERB ( verb ) tag = verb, gerund or present participle
# teledigital  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# calculators  =  NOUN ( noun ) tag = noun, plural
# to  =  PART ( particle ) tag = infinitival "to"
# gather  =  VERB ( verb ) tag = verb, base form
# capital  =  NOUN ( noun ) tag = noun, singular or mass
# for  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# their  =  PRON ( pronoun ) tag = pronoun, possessive
# main  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# product  =  NOUN ( noun ) tag = noun, singular or mass
# On  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# 11  =  NUM ( numeral ) tag = cardinal number
# August  =  PROPN ( proper noun ) tag = noun, proper singular
# 1976  =  NUM ( numeral ) tag = cardinal number
# the  =  DET ( determiner ) tag = determiner
# company  =  NOUN ( noun ) tag = noun, singular or mass
# was  =  AUX ( auxiliary ) tag = verb, past tense
# renamed  =  VERB ( verb ) tag = verb, past participle
# Hindustan  =  PROPN ( proper noun ) tag = noun, proper singular
# Computers  =  PROPN ( proper noun ) tag = noun, proper plural
# Limited  =  PROPN ( proper noun ) tag = noun, proper singular
# HCL).[12  =  PROPN ( proper noun ) tag = noun, proper singular
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# Enterprise  =  PROPN ( proper noun ) tag = noun, proper singular
# developed  =  VERB ( verb ) tag = verb, past tense
# an  =  DET ( determiner ) tag = determiner
# indigenous  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# microcomputer  =  NOUN ( noun ) tag = noun, singular or mass
# in  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# 1978,[13  =  NUM ( numeral ) tag = cardinal number
# and  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# a  =  DET ( determiner ) tag = determiner
# RDBMS  =  NOUN ( noun ) tag = noun, singular or mass
# networking  =  VERB ( verb ) tag = verb, gerund or present participle
# OS  =  NOUN ( noun ) tag = noun, singular or mass
# and  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# client  =  NOUN ( noun ) tag = noun, singular or mass
# server  =  NOUN ( noun ) tag = noun, singular or mass
# architecture  =  NOUN ( noun ) tag = noun, singular or mass
# in  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# 1983.[14  =  PROPN ( proper noun ) tag = noun, proper singular
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# Technologies  =  PROPN ( proper noun ) tag = noun, proper plural
# began  =  VERB ( verb ) tag = verb, past tense
# as  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# the  =  DET ( determiner ) tag = determiner
# R&D  =  PROPN ( proper noun ) tag = noun, proper singular
# division  =  NOUN ( noun ) tag = noun, singular or mass
# of  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# The  =  DET ( determiner ) tag = determiner
# company  =  NOUN ( noun ) tag = noun, singular or mass
# originally  =  ADV ( adverb ) tag = adverb
# was  =  AUX ( auxiliary ) tag = verb, past tense
# focused  =  VERB ( verb ) tag = verb, past participle
# on  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# hardware  =  NOUN ( noun ) tag = noun, singular or mass
# but  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# via  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# Technologies  =  PROPN ( proper noun ) tag = noun, proper plural
# software  =  NOUN ( noun ) tag = noun, singular or mass
# and  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# services  =  NOUN ( noun ) tag = noun, plural
# became  =  VERB ( verb ) tag = verb, past tense
# the  =  DET ( determiner ) tag = determiner
# main  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# focus.[16][17  =  NOUN ( noun ) tag = noun, singular or mass
# On  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# 12  =  NUM ( numeral ) tag = cardinal number
# November  =  PROPN ( proper noun ) tag = noun, proper singular
# 1991  =  NUM ( numeral ) tag = cardinal number
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# Technologies  =  PROPN ( proper noun ) tag = noun, proper singular
# was  =  AUX ( auxiliary ) tag = verb, past tense
# spun  =  VERB ( verb ) tag = verb, past participle
# off  =  ADP ( adposition ) tag = adverb, particle
# as  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# a  =  DET ( determiner ) tag = determiner
# separate  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# unit,[18  =  NOUN ( noun ) tag = noun, plural
# being  =  AUX ( auxiliary ) tag = verb, gerund or present participle
# incorporated  =  VERB ( verb ) tag = verb, past participle
# as  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# Overseas  =  PROPN ( proper noun ) tag = noun, proper singular
# Limited  =  PROPN ( proper noun ) tag = noun, proper singular
# a  =  DET ( determiner ) tag = determiner
# provider  =  NOUN ( noun ) tag = noun, singular or mass
# of  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# software  =  NOUN ( noun ) tag = noun, singular or mass
# and  =  CCONJ ( coordinating conjunction ) tag = conjunction, coordinating
# technology  =  NOUN ( noun ) tag = noun, singular or mass
# development  =  NOUN ( noun ) tag = noun, singular or mass
# In  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# 1993  =  NUM ( numeral ) tag = cardinal number
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# also  =  ADV ( adverb ) tag = adverb
# started  =  VERB ( verb ) tag = verb, past tense
# providing  =  VERB ( verb ) tag = verb, gerund or present participle
# enterprise  =  NOUN ( noun ) tag = noun, singular or mass
# IT  =  PROPN ( proper noun ) tag = noun, proper singular
# infrastructure  =  NOUN ( noun ) tag = noun, singular or mass
# management  =  NOUN ( noun ) tag = noun, singular or mass
# services  =  NOUN ( noun ) tag = noun, plural
# winning  =  VERB ( verb ) tag = verb, gerund or present participle
# an  =  DET ( determiner ) tag = determiner
# order  =  NOUN ( noun ) tag = noun, singular or mass
# to  =  PART ( particle ) tag = infinitival "to"
# establish  =  VERB ( verb ) tag = verb, base form
# India  =  PROPN ( proper noun ) tag = noun, proper singular
# 's  =  PART ( particle ) tag = possessive ending
# first  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# floorless  =  NOUN ( noun ) tag = noun, singular or mass
# electronic  =  ADJ ( adjective ) tag = adjective (English), other noun-modifier (Chinese)
# stock  =  NOUN ( noun ) tag = noun, singular or mass
# exchange  =  NOUN ( noun ) tag = noun, singular or mass
# for  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# NSE.[20][21  =  PROPN ( proper noun ) tag = noun, proper singular
# In  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# July  =  PROPN ( proper noun ) tag = noun, proper singular
# 1994  =  NUM ( numeral ) tag = cardinal number
# the  =  DET ( determiner ) tag = determiner
# company  =  NOUN ( noun ) tag = noun, singular or mass
# name  =  NOUN ( noun ) tag = noun, singular or mass
# was  =  AUX ( auxiliary ) tag = verb, past tense
# changed  =  VERB ( verb ) tag = verb, past participle
# to  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# Consulting  =  PROPN ( proper noun ) tag = noun, proper singular
# Limited.[22  =  ADV ( adverb ) tag = adverb
# On  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# 6  =  NUM ( numeral ) tag = cardinal number
# October  =  PROPN ( proper noun ) tag = noun, proper singular
# 1999  =  NUM ( numeral ) tag = cardinal number
# the  =  DET ( determiner ) tag = determiner
# company  =  NOUN ( noun ) tag = noun, singular or mass
# was  =  AUX ( auxiliary ) tag = verb, past tense
# renamed  =  VERB ( verb ) tag = verb, past participle
# HCL  =  PROPN ( proper noun ) tag = noun, proper singular
# Technologies  =  PROPN ( proper noun ) tag = noun, proper plural
# Limited  =  PROPN ( proper noun ) tag = noun, proper singular
# for  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# a  =  DET ( determiner ) tag = determiner
# better  =  ADJ ( adjective ) tag = adjective, comparative
# reflection  =  NOUN ( noun ) tag = noun, singular or mass
# of  =  ADP ( adposition ) tag = conjunction, subordinating or preposition
# its  =  PRON ( pronoun ) tag = pronoun, possessive
# activities  =  NOUN ( noun ) tag = noun, plural
